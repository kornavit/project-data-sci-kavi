# %% [markdown]
# # รายชื่อกลุ่ม
# * นาย กรณวิทย์ พัฒนโชควานิช 6410450079
# * นาย รัชพล หินซุย 6410450257
# * นาย ปาณชัย คชกาษร 6410450176
# * นาย ธนดล กฤตวีรนันท์ 6410450974
#
# ---

# %% [markdown]
# ## อธิบายถึงข้อมูล
# Kiva.org เป็นแพลตฟอร์มการระดมทุนออนไลน์เพื่อขยายบริการทางการเงินให้กับคนยากจนและถูกกีดกันทางการเงินทั่วโลก ผู้ให้กู้ Kiva ได้ให้เงินกู้ยืมมากกว่า 1 พันล้านดอลลาร์แก่ผู้คนกว่า 2 ล้านคน เพื่อกำหนดลำดับความสำคัญของการลงทุน ช่วยแจ้งผู้ให้กู้ และทำความเข้าใจกับชุมชนเป้าหมาย การทราบระดับความยากจนของผู้กู้แต่ละรายเป็นสิ่งสำคัญ อย่างไรก็ตาม ต้องใช้การอนุมานตามชุดข้อมูลที่จำกัดสำหรับผู้กู้แต่ละราย
#
# ## ที่มาของข้อมูล
# https://www.kaggle.com/datasets/kiva/data-science-for-good-kiva-crowdfunding?resource=download
#
#
# ## ข้อมูลชุดนี้คนเก็บโดย
# Kiva Crowdfunding
#
# ## รายละเอียดแต่ละ columns
# * id: เลขประจำตัวของสัญญากู้ยืมเงิน (loan) บนแพลตฟอร์ม Kiva
# * funded_amount: จำนวนเงินที่ได้รับการสนับสนุน (funding) จากผู้ให้กู้ในสัญญานี้
# * loan_amount: จำนวนเงินที่ถูกขอกู้ในสัญญานี้
# * activity: กิจกรรมหลักที่ผู้กู้ต้องการใช้เงินกู้ในการดำเนินชีวิต
# * sector: ภูมิภาคของกิจกรรมหลัก (เช่น การศึกษา, การผลิต, การค้าส่ง)
# * use: วัตถุประสงค์หลักที่ผู้กู้ต้องการใช้เงินกู้
# * country_code: รหัสประเทศของที่อยู่ของผู้กู้
# * country: ชื่อประเทศของที่อยู่ของผู้กู้
# * region: ชื่อของเมืองหรือชื่อภูมิภาค
# * currency: สกุลเงินที่ใช้ในสัญญานี้
# * partner_id: รหัสพันธมิตรที่เชื่อมโยงกับสัญญานี้ (หน่วยงานที่ช่วยสนับสนุนการกู้ยืมเงินใน Kiva)
# * posted_time: วันที่และเวลาที่สัญญาถูกโพสต์บนแพลตฟอร์ม Kiva
# * disbursed_time: วันที่และเวลาที่เงินกู้
# * funded_time: วันที่และเวลาที่เงินกู้ถูกเตมเตมจนสมบรณบนแพลตฟอรม Kiva
# * term_in_months: ระยะเวลาที่ต้องชำระต่อเดือน
# * lender_count: จำนวนผู้ให้กู้ที่มีส่วนร่วมในการสนับสนุนสัญญาที่บัญชาใน 1 การกู้
# * tags: แทกทเกยวของกบสญญาน (คำอธบายยอยเกยวกบการใชเงนก)
# * borrower_genders: เพศของผู้กู้
# * repayment_interval: รูปแบบการชำระเงินกู้ (รายเดือน, รายปี, ไม่ระบุ)
# * date: วันที่และเวลาที่สัญญาถูกนำเข้ามายงฐานขอมลของ Kiva
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('dataset/kiva_loans.csv')

# %%
df
# Out:
#              id  funded_amount  loan_amount             activity  \
# 0        653051          300.0        300.0  Fruits & Vegetables
# 1        653053          575.0        575.0             Rickshaw
# 2        653068          150.0        150.0       Transportation
# 3        653063          200.0        200.0           Embroidery
# 4        653084          400.0        400.0           Milk Sales
# ...         ...            ...          ...                  ...
# 671200  1340323            0.0         25.0            Livestock
# 671201  1340316           25.0         25.0            Livestock
# 671202  1340334            0.0         25.0                Games
# 671203  1340338            0.0         25.0            Livestock
# 671204  1340339            0.0         25.0            Livestock
#
#                 sector                                                use  \
# 0                 Food            To buy seasonal, fresh fruits to sell.
# 1       Transportation  to repair and maintain the auto rickshaw used ...
# 2       Transportation  To repair their old cycle-van and buy another ...
# 3                 Arts  to purchase an embroidery machine and a variet...
# 4                 Food                           to purchase one buffalo.
# ...                ...                                                ...
# 671200     Agriculture  [True, u'para compara: cemento, arenya y ladri...
# 671201     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671202   Entertainment                                                NaN
# 671203     Agriculture  [True, u'to start a turducken farm.'] - this l...
# 671204     Agriculture  [True, u'to start a turducken farm.'] - this l...
#
#        country_code   country        region currency  partner_id  \
# 0                PK  Pakistan        Lahore      PKR       247.0
# 1                PK  Pakistan        Lahore      PKR       247.0
# 2                IN     India     Maynaguri      INR       334.0
# 3                PK  Pakistan        Lahore      PKR       247.0
# 4                PK  Pakistan  Abdul Hakeem      PKR       245.0
# ...             ...       ...           ...      ...         ...
# 671200           PY  Paraguay    Concepción      USD        58.0
# 671201           KE     Kenya           NaN      KES       138.0
# 671202           KE     Kenya           NaN      KES       138.0
# 671203           KE     Kenya           NaN      KES       138.0
# 671204           KE     Kenya           NaN      KES       138.0
#
#                       posted_time             disbursed_time  \
# 0       2014-01-01 06:12:39+00:00  2013-12-17 08:00:00+00:00
# 1       2014-01-01 06:51:08+00:00  2013-12-17 08:00:00+00:00
# 2       2014-01-01 09:58:07+00:00  2013-12-17 08:00:00+00:00
# 3       2014-01-01 08:03:11+00:00  2013-12-24 08:00:00+00:00
# 4       2014-01-01 11:53:19+00:00  2013-12-17 08:00:00+00:00
# ...                           ...                        ...
# 671200  2017-07-25 16:55:34+00:00  2017-07-25 07:00:00+00:00
# 671201  2017-07-25 06:14:08+00:00  2017-07-24 07:00:00+00:00
# 671202  2017-07-26 00:02:07+00:00  2017-07-25 07:00:00+00:00
# 671203  2017-07-26 06:12:55+00:00  2017-07-25 07:00:00+00:00
# 671204  2017-07-26 06:31:46+00:00  2017-07-25 07:00:00+00:00
#
#                       funded_time  term_in_months  lender_count  \
# 0       2014-01-02 10:06:32+00:00            12.0            12
# 1       2014-01-02 09:17:23+00:00            11.0            14
# 2       2014-01-01 16:01:36+00:00            43.0             6
# 3       2014-01-01 13:00:00+00:00            11.0             8
# 4       2014-01-01 19:18:51+00:00            14.0            16
# ...                           ...             ...           ...
# 671200                        NaN            13.0             0
# 671201  2017-07-26 02:09:43+00:00            13.0             1
# 671202                        NaN            13.0             0
# 671203                        NaN            13.0             0
# 671204                        NaN            13.0             0
#
#                                 tags borrower_genders repayment_interval  \
# 0                                NaN           female          irregular
# 1                                NaN   female, female          irregular
# 2       user_favorite, user_favorite           female             bullet
# 3                                NaN           female          irregular
# 4                                NaN           female            monthly
# ...                              ...              ...                ...
# 671200                           NaN           female            monthly
# 671201                           NaN           female            monthly
# 671202                           NaN              NaN            monthly
# 671203                           NaN           female            monthly
# 671204                           NaN           female            monthly
#
#               date
# 0       2014-01-01
# 1       2014-01-01
# 2       2014-01-01
# 3       2014-01-01
# 4       2014-01-01
# ...            ...
# 671200  2017-07-25
# 671201  2017-07-25
# 671202  2017-07-26
# 671203  2017-07-26
# 671204  2017-07-26
#
# [671205 rows x 20 columns]

# %% [markdown]
# # เอาค่าออกมาดูว่ามีอะไรบ้าง

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  671205 non-null  int64
#  1   funded_amount       671205 non-null  float64
#  2   loan_amount         671205 non-null  float64
#  3   activity            671205 non-null  object
#  4   sector              671205 non-null  object
#  5   use                 666973 non-null  object
#  6   country_code        671197 non-null  object
#  7   country             671205 non-null  object
#  8   region              614405 non-null  object
#  9   currency            671205 non-null  object
#  10  partner_id          657698 non-null  float64
#  11  posted_time         671205 non-null  object
#  12  disbursed_time      668809 non-null  object
#  13  funded_time         622874 non-null  object
#  14  term_in_months      671205 non-null  float64
#  15  lender_count        671205 non-null  int64
#  16  tags                499789 non-null  object
#  17  borrower_genders    666984 non-null  object
#  18  repayment_interval  671205 non-null  object
#  19  date                671205 non-null  object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 102.4+ MB

# %% [markdown]
# # เอาค่ามาเปลี่ยนเป็น datetime ใน columns date

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['count'] = 1

# %% [markdown]
# # เช็ดว่ามี columns ไหนเป็น null บ้าง

# %%
df.isnull().sum()
# Out:
# id                         0
# funded_amount              0
# loan_amount                0
# activity                   0
# sector                     0
# use                     4232
# country_code               8
# country                    0
# region                 56800
# currency                   0
# partner_id             13507
# posted_time                0
# disbursed_time          2396
# funded_time            48331
# term_in_months             0
# lender_count               0
# tags                  171416
# borrower_genders        4221
# repayment_interval         0
# date                       0
# count                      0
# dtype: int64

# %% [markdown]
# # คัดเอาแค่ row ที่ไม่มี null

# %%
df = df.loc[(df['id'].notna()) &
        (df['country'].notna()) &
        (df['region'].notna()) &
        (df['tags'].notna()) &
        (df['partner_id'].notna())]

# %%
df
# Out:
#              id  funded_amount  loan_amount                   activity  \
# 2        653068          150.0        150.0             Transportation
# 6        653067          200.0        200.0                      Dairy
# 7        653078          400.0        400.0               Beauty Salon
# 8        653082          475.0        475.0              Manufacturing
# 12       653089          400.0        400.0              General Store
# ...         ...            ...          ...                        ...
# 671145  1339668          175.0        775.0                    Flowers
# 671146  1339916            0.0        700.0                  Livestock
# 671147  1339743            0.0        250.0                 Food Stall
# 671148  1339874            0.0        400.0  Personal Medical Expenses
# 671149  1339686          100.0        775.0  Personal Housing Expenses
#
#                 sector                                                use  \
# 2       Transportation  To repair their old cycle-van and buy another ...
# 6          Agriculture  To purchase a dairy cow and start a milk produ...
# 7             Services         to buy more hair and skin care products.
# 8        Manufacturing  to purchase leather, plastic soles and heels i...
# 12              Retail            to buy stock of rice, sugar and flour .
# ...                ...                                                ...
# 671145     Agriculture  to purchase seedlings, pots for flowers and fe...
# 671146     Agriculture    to purchase livestock and expand her activities
# 671147            Food         to buy watermelon to start a new business.
# 671148          Health   to pay for her son's immediate medical treatment
# 671149         Housing  to install 5 new windows and save heat in winter.
#
#        country_code     country       region currency  ...  \
# 2                IN       India    Maynaguri      INR  ...
# 6                IN       India    Maynaguri      INR  ...
# 7                PK    Pakistan    Ellahabad      PKR  ...
# 8                PK    Pakistan       Lahore      PKR  ...
# 12               PK    Pakistan   Faisalabad      PKR  ...
# ...             ...         ...          ...      ...  ...
# 671145           UA     Ukraine  Vinogradovo      UAH  ...
# 671146           TJ  Tajikistan     Khuroson      TJS  ...
# 671147           TJ  Tajikistan     Spitamen      TJS  ...
# 671148           TJ  Tajikistan       Isfara      TJS  ...
# 671149           UA     Ukraine  Vinogradovo      UAH  ...
#
#                       posted_time             disbursed_time  \
# 2       2014-01-01 09:58:07+00:00  2013-12-17 08:00:00+00:00
# 6       2014-01-01 09:51:02+00:00  2013-12-16 08:00:00+00:00
# 7       2014-01-01 11:46:01+00:00  2013-12-20 08:00:00+00:00
# 8       2014-01-01 11:49:43+00:00  2013-12-20 08:00:00+00:00
# 12      2014-01-01 12:04:57+00:00  2013-12-24 08:00:00+00:00
# ...                           ...                        ...
# 671145  2017-07-14 04:06:08+00:00  2017-07-05 07:00:00+00:00
# 671146  2017-07-14 12:07:02+00:00  2017-07-04 07:00:00+00:00
# 671147  2017-07-14 06:32:27+00:00  2017-07-14 07:00:00+00:00
# 671148  2017-07-14 09:51:17+00:00  2017-07-13 07:00:00+00:00
# 671149  2017-07-14 04:30:33+00:00  2017-07-10 07:00:00+00:00
#
#                       funded_time term_in_months  lender_count  \
# 2       2014-01-01 16:01:36+00:00           43.0             6
# 6       2014-01-01 17:18:09+00:00           43.0             8
# 7       2014-01-10 18:18:44+00:00           14.0             8
# 8       2014-01-01 18:47:21+00:00           14.0            19
# 12      2014-01-08 00:35:14+00:00           14.0            16
# ...                           ...            ...           ...
# 671145                        NaN           12.0             7
# 671146                        NaN           14.0             0
# 671147                        NaN           14.0             0
# 671148                        NaN           14.0             0
# 671149                        NaN           14.0             4
#
#                                                      tags borrower_genders  \
# 2                            user_favorite, user_favorite           female
# 6                            user_favorite, user_favorite           female
# 7                              #Elderly, #Woman Owned Biz           female
# 8                                           user_favorite           female
# 12                     #Repeat Borrower, #Woman Owned Biz           female
# ...                                                   ...              ...
# 671145  user_favorite, #Parent, #Biz Durable Asset, #V...             male
# 671146                                           #Animals           female
# 671147                                           #Elderly             male
# 671148                             #Health and Sanitation           female
# 671149                     #Parent, #Repair Renew Replace           female
#
#        repayment_interval       date count
# 2                  bullet 2014-01-01     1
# 6                  bullet 2014-01-01     1
# 7                 monthly 2014-01-01     1
# 8                 monthly 2014-01-01     1
# 12                monthly 2014-01-01     1
# ...                   ...        ...   ...
# 671145            monthly 2017-07-14     1
# 671146            monthly 2017-07-14     1
# 671147            monthly 2017-07-14     1
# 671148            monthly 2017-07-14     1
# 671149            monthly 2017-07-14     1
#
# [462171 rows x 21 columns]

# %%
dfgroupby = df.groupby('country').sum()

# %%
dfgroupby.sort_values(by='count',ascending=False).head()
# Out:
#                       id  funded_amount  loan_amount  partner_id  \
# country
# Philippines  97297141216     34725625.0   35558400.0  13276769.0
# Kenya        54336428483     25646400.0   27778175.0   9660023.0
# Cambodia     29627564522     15489025.0   16518900.0   6221031.0
# Pakistan     23663309735     10754375.0   11550050.0   6136369.0
# Colombia     18460412680     10798325.0   12637125.0   3223826.0
#
#              term_in_months  lender_count  count
# country
# Philippines        991308.0        951345  94051
# Kenya              717585.0        770440  52360
# Cambodia           386887.0        468366  27135
# Pakistan           306222.0        325329  22542
# Colombia           335711.0        318591  18453

# %% [markdown]
# # ข้อมูลทั้งหมดดูเหมาะสมและครอบคลุมแล้ว
# ## กลุ่มของนิสิตตัดออกในพวกค่าที่มี null ที่จะทำให้ไม่สามารถคิดในทางสถิติได้

# %% [markdown]
# ---

# %% [markdown]
# # คำถามที่น่าสนใจ

# %% [markdown]
# # หาความแตกต่างกันว่าอัตตราการกู้ของ 5 ประเทศที่มากที่สุดในแต่ละเรื่องว่ามีอันไหนที่ควรปรับบ้าง

# %% [markdown]
# ## เอา columns count ออกจาก ตาราง

# %%
df = df.drop(columns='count')

# %% [markdown]
# ## เอาแค่ 5 ประเทศที่มีการกู้ยืมมากที่สุด

# %%
df = df[(df.country == 'Philippines') | 
   (df.country == 'Kenya') | 
   (df.country == 'Cambodia') | 
   (df.country == 'Pakistan') | 
   (df.country == 'Colombia')]

# %%
df
# Out:
#              id  funded_amount  loan_amount                 activity  \
# 7        653078          400.0        400.0             Beauty Salon
# 8        653082          475.0        475.0            Manufacturing
# 12       653089          400.0        400.0            General Store
# 16       653091          400.0        400.0            General Store
# 19       653080          475.0        475.0             Beauty Salon
# ...         ...            ...          ...                      ...
# 671082  1338497           25.0       1000.0                     Pigs
# 671085  1338640           50.0        375.0                   Sewing
# 671087  1338628            0.0        675.0  Personal Products Sales
# 671091  1338627            0.0        400.0           Clothing Sales
# 671104  1338384           50.0        700.0                Livestock
#
#                sector                                                use  \
# 7            Services         to buy more hair and skin care products.
# 8       Manufacturing  to purchase leather, plastic soles and heels i...
# 12             Retail            to buy stock of rice, sugar and flour .
# 16             Retail     to buy packs of salts, biscuits and beverages.
# 19           Services  to buy more cosmetics products for her beauty ...
# ...               ...                                                ...
# 671082    Agriculture  purchase more piglets and concentrate to feed ...
# 671085       Services  to buy fabric and sewing supplies in order to ...
# 671087         Retail  to buy merchandise such as lotions, baby powde...
# 671091       Clothing  to buy women's clothing such as blouses, pants...
# 671104    Agriculture                         to buy livestock to raise.
#
#        country_code   country                region currency  partner_id  \
# 7                PK  Pakistan             Ellahabad      PKR       245.0
# 8                PK  Pakistan                Lahore      PKR       245.0
# 12               PK  Pakistan            Faisalabad      PKR       245.0
# 16               PK  Pakistan            Faisalabad      PKR       245.0
# 19               PK  Pakistan                Lahore      PKR       245.0
# ...             ...       ...                   ...      ...         ...
# 671082           CO  Colombia              Valencia      COP       177.0
# 671085           CO  Colombia          Barranquilla      COP       154.0
# 671087           CO  Colombia                 turbo      COP       177.0
# 671091           CO  Colombia             Marinilla      COP       177.0
# 671104           CO  Colombia  El Carmen de Bolivar      COP       177.0
#
#                       posted_time             disbursed_time  \
# 7       2014-01-01 11:46:01+00:00  2013-12-20 08:00:00+00:00
# 8       2014-01-01 11:49:43+00:00  2013-12-20 08:00:00+00:00
# 12      2014-01-01 12:04:57+00:00  2013-12-24 08:00:00+00:00
# 16      2014-01-01 12:09:10+00:00  2013-12-09 08:00:00+00:00
# 19      2014-01-01 11:48:08+00:00  2013-12-19 08:00:00+00:00
# ...                           ...                        ...
# 671082  2017-07-12 16:34:25+00:00  2017-06-13 07:00:00+00:00
# 671085  2017-07-12 21:50:45+00:00  2017-06-14 07:00:00+00:00
# 671087  2017-07-12 21:25:33+00:00  2017-06-23 07:00:00+00:00
# 671091  2017-07-12 21:23:36+00:00  2017-06-23 07:00:00+00:00
# 671104  2017-07-12 15:04:28+00:00  2017-06-22 07:00:00+00:00
#
#                       funded_time  term_in_months  lender_count  \
# 7       2014-01-10 18:18:44+00:00            14.0             8
# 8       2014-01-01 18:47:21+00:00            14.0            19
# 12      2014-01-08 00:35:14+00:00            14.0            16
# 16      2014-01-14 15:57:05+00:00            14.0            11
# 19      2014-01-10 03:22:29+00:00            14.0            18
# ...                           ...             ...           ...
# 671082                        NaN            20.0             1
# 671085                        NaN            13.0             2
# 671087                        NaN            26.0             0
# 671091                        NaN            26.0             0
# 671104                        NaN            26.0             2
#
#                                       tags borrower_genders  \
# 7               #Elderly, #Woman Owned Biz           female
# 8                            user_favorite           female
# 12      #Repeat Borrower, #Woman Owned Biz           female
# 16               #Woman Owned Biz, #Parent           female
# 19                        #Woman Owned Biz           female
# ...                                    ...              ...
# 671082          #Animals, #Woman Owned Biz           female
# 671085             #Fabrics, user_favorite           female
# 671087                    #Woman Owned Biz           female
# 671091                    #Woman Owned Biz           female
# 671104             #Animals, user_favorite             male
#
#        repayment_interval       date
# 7                 monthly 2014-01-01
# 8                 monthly 2014-01-01
# 12                monthly 2014-01-01
# 16                monthly 2014-01-01
# 19                monthly 2014-01-01
# ...                   ...        ...
# 671082             bullet 2017-07-12
# 671085            monthly 2017-07-12
# 671087             bullet 2017-07-12
# 671091             bullet 2017-07-12
# 671104             bullet 2017-07-12
#
# [214541 rows x 20 columns]

# %% [markdown]
# ## ทำการ plot graph ทำให้เห็นได้ว่าแต่ละประเทศนั้นมีการกู้ในแต่ละอย่างที่แตกต่างกัน

# %%
sns.catplot(data = df, x = 'country', y = 'loan_amount',hue='sector')

# %% [markdown]
# ## ทำการรวมแล้วหาว่า ค่าที่มากที่สุดที่ในการกู้ยืมคืออะไร

# %%
df = df.groupby(['country','sector']).sum().loc[:,['funded_amount','loan_amount']]

# %%
df.loc['Pakistan'].sort_values('loan_amount',ascending = False).head(1)
# Out:
#           funded_amount  loan_amount
# sector
# Services      2188800.0    2318075.0

# %%
df.loc['Kenya'].sort_values('loan_amount',ascending = False).head(1)
# Out:
#              funded_amount  loan_amount
# sector
# Agriculture     13852800.0   14923575.0

# %%
df.loc['Cambodia'].sort_values('loan_amount',ascending = False).head(1)
# Out:
#              funded_amount  loan_amount
# sector
# Agriculture      7397400.0    8128550.0

# %%
df.loc['Philippines'].sort_values('loan_amount',ascending = False).head(1)
# Out:
#         funded_amount  loan_amount
# sector
# Retail     11926125.0   12306600.0

# %%
df.loc['Colombia'].sort_values('loan_amount',ascending = False).head(1)
# Out:
#         funded_amount  loan_amount
# sector
# Retail      2527775.0    3097875.0

# %% [markdown]
# ## สรุปได้ว่าแต่ละเรื่องควรที่ให้ มีอัตราความยากจนที่ไม่เท่าไหร่ ทำให้เรารู้ว่าแต่ละประเทศมีการขาดแคลนในเรื่องไหนบ้างเพื่อให้สามารถปรับอัตตราการกู้ยืมได้ เช่น
# - ประเทศ Pakistan เรื้อง บริการ (Services) คิดว่าบริษัท kiva ควรจะสลับเงินทุนที่เกี่ยวกับ การบริการ มากขี้น
# - ประเทศ Kenya เรื่อง เกษตรกรรม (Agriculture) คิดว่าบริษัท kiva ควรจะสลับเงินทุนที่เกี่ยวกับ การเกษตรกรรม มากขี้น
# - ประเทศ Cambodia เรื่อง เกษตรกรรม (Agriculture) คิดว่าบริษัท kiva ควรจะสลับเงินทุนที่เกี่ยวกับ การเกษตรกรรม มากขี้น
# - ประเทศ Philippines เรื่อง ขายปลีก (Retail) คิดว่าบริษัท kiva ควรจะสลับเงินทุนที่เกี่ยวกับ การค่าปลีก มากขี้น
# - ประเทศ Colombia เรื่อง ขายปลีก (Retail) คิดว่าบริษัท kiva ควรจะสลับเงินทุนที่เกี่ยวกับ การค่าปลีก มากขี้น
